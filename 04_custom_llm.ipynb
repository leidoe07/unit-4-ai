# %%
import gpt_2_simple as gpt2

session = gpt2.start_tf_sess()

# %%
# gpt2.download_gpt2(
#     model_name='124M'
# )
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 2.05Git/s]
# Fetching encoder.json: 1.05Mit [00:00, 3.17Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 14.0Git/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:55, 9.02Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 4.38Git/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 5.83Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 5.28Mit/s]

# %%
# gpt2.load_gpt2(session, model_name='124M',reuse=True)
gpt2.finetune(
    session, 
	"minecraft.txt", 
	model_name="124M", 
	steps=100, 
	run_name="minecraft"
)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732722030.107102 5906275 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled
# Loading checkpoint checkpoint/minecraft/model-229
# INFO:tensorflow:Restoring parameters from checkpoint/minecraft/model-229
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # gpt2.load_gpt2(session, model_name='124M',reuse=True)
# ----> 2 gpt2.finetune(
#       3     session,
#       4 	"minecraft.txt",
#       5 	model_name="124M",
#       6 	steps=100,
#       7 	run_name="minecraft"
#       8 )
#
# ...

# %%
gpt2.generate(
    session, 
    prefix="Q: What is Minecraft?",
    run_name="minecraft",)
# Out:
# Q: What is Minecraft?
# A: Minecraft - 1.21.4
#
# Q: When was Minecraft released?
# A: Minecraft was officially released on November 18, 2011.
#
# Q: When was multiplayer added to Minecraft?
# A: Multiplayer was added to Minecraft on June 8, 2009, during its early development stage.
#
# Q: What was the first edition of Minecraft?
# A: The first edition of Minecraft was Minecraft Classic, released on May 17, 2009.
#
# Q: When was Minecraft Bedrock Edition released?
# A: Minecraft Bedrock Edition was released on September 20, 2017.
#
# Q: When was Minecraft Pocket Edition released?
# A: Minecraft Pocket Edition was released on August 16, 2011.
#
# Q: Who is the original developer of Minecraft?
# A: The original developer of Minecraft is Markus Persson, also known as “Notch.”
#
# Q: How does Mojang Studio relate to Minecraft?
# A: Mojang Studios, founded by Markus Persson, is the original studio that developed and published Minecraft.
#
# Q: Who currently owns Minecraft?
# ...

# %%
gpt2.generate(
    session, 
    prefix="Q: Who is 'Notch'",
    run_name="minecraft",)
# Out:
# Q: Who is 'Notch'?
# A: Notch is the first Minecraft game to be released.
#
# Q: When was multiplayer added to Minecraft?
# A: Multiplayer was added to Minecraft on June 8, 2009, during its early development stage.
#
# Q: What was the first edition of Minecraft?
# A: The first edition of Minecraft was Minecraft Classic, released on May 17, 2009.
#
# Q: When was Minecraft Bedrock Edition released?
# A: Minecraft Bedrock Edition was released on September 20, 2017.
#
# Q: When was Minecraft Pocket Edition released?
# A: Minecraft Pocket Edition was released on August 16, 2011.
#
# Q: Who is the original developer of Minecraft?
# A: The original developer of Minecraft is Markus Persson, also known as “Notch.”
#
# Q: How does Mojang Studio relate to Minecraft?
# A: Mojang Studios, founded by Markus Persson, is the original studio that developed and published Minecraft.
#
# Q: Who currently owns Minecraft?
# ...

# %%
gpt2.generate(
    session, 
    prefix="Q: How old is Minecraft?",
    run_name="minecraft",)
# Out:
# Q: How old is Minecraft?
# A: Minecraft - 1.21.4
#
# Q: When was Minecraft released?
# A: Minecraft was officially released on November 18, 2011.
#
# Q: When was multiplayer added to Minecraft?
# A: Multiplayer was added to Minecraft on June 8, 2009, during its early development stage.
#
# Q: What was the first edition of Minecraft?
# A: The first edition of Minecraft was Minecraft Classic, released on May 17, 2009.
#
# Q: When was Minecraft Bedrock Edition released?
# A: Minecraft Bedrock Edition was released on September 20, 2017.
#
# Q: When was Minecraft Pocket Edition released?
# A: Minecraft Pocket Edition was released on August 16, 2011.
#
# Q: Who is the original developer of Minecraft?
# A: The original developer of Minecraft is Markus Persson, also known as “Notch.”
#
# Q: How does Mojang Studio relate to Minecraft?
# A: Mojang Studios, founded by Markus Persson, is the original studio that developed and published Minecraft.
#
# Q: Who currently owns Minecraft?
# ...
